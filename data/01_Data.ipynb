# %%
import sys
!"{sys.executable}" -m pip install yfinance pandas numpy matplotlib seaborn torch scikit-learn scipy
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached torch-2.12.0-cp314-cp314-win_amd64.whl.metadata (31 kB)
# ...
#   Using cached scikit_learn-1.8.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#   Using cached markupsafe-3.0.3-cp314-cp314-win_amd64.whl.metadata (2.8 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("All imports working")
# Out:
# All imports working

# %%
df = yf.download('AAPL', start='2018-01-01', end='2024-01-01')
print(df.head())
print(df.shape)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# 2018-01-02  40.267078  40.276431  39.565806  39.776190  102223600
# 2018-01-03  40.260056  40.802375  40.196944  40.330184  118071600
# 2018-01-04  40.447063  40.549917  40.224995  40.332521   89738400
# 2018-01-05  40.907566  40.994055  40.451740  40.542905   94640000
# 2018-01-08  40.755630  41.050164  40.657449  40.755630   82271200
# (1509, 5)

# %%
print(df.info())
print()
print(df.describe())
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 1509 entries, 2018-01-02 to 2023-12-29
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   1509 non-null   float64
#  1   (High, AAPL)    1509 non-null   float64
#  2   (Low, AAPL)     1509 non-null   float64
#  3   (Open, AAPL)    1509 non-null   float64
#  4   (Volume, AAPL)  1509 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 70.7 KB
# None
#
# Price         Close         High          Low         Open        Volume
# Ticker         AAPL         AAPL         AAPL         AAPL          AAPL
# count   1509.000000  1509.000000  1509.000000  1509.000000  1.509000e+03
# mean     107.624452   108.750002   106.386596   107.524682  1.073284e+08
# std       50.839640    51.312564    50.313080    50.798742  5.513287e+07
# min       33.736996    34.574548    33.691914    34.161702  2.404830e+07
# ...

# %%
prices = df['Close']['AAPL']
print(prices.head())
print(type(prices))
# Out:
# 2018-01-02    40.267078
# 2018-01-03    40.260056
# 2018-01-04    40.447063
# 2018-01-05    40.907566
# 2018-01-08    40.755630
# Name: AAPL, dtype: float64
# <class 'pandas.Series'>

# %%
prices.plot(figsize=(12, 4), title='AAPL Adjusted Close 2018–2024')
plt.ylabel('Price ($)')
plt.show()

# %%
df.to_csv("data/aapl_raw.csv", index=False)

# %%
import os

for root, dirs, files in os.walk(r"D:\Coding\stock-predictor"):
    for file in files:
        if file.endswith(".ipynb"):
            print(os.path.join(root, file))
